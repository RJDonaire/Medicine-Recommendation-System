# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import re
import html
from nltk import tokenize
from nltk.sentiment.vader import SentimentIntensityAnalyzer

import os

# %%
path_dataset = './datasets/'

datasets = os.listdir(path_dataset)

test = pd.read_csv(path_dataset + datasets[0])
train = pd.read_csv(path_dataset + datasets[1])

drugs_pd = test.append(train, ignore_index = True)
drugs_pd
# Out:
#         uniqueID            drugName                     condition  \
# 0         163740         Mirtazapine                    Depression
# 1         206473          Mesalamine  Crohn's Disease, Maintenance
# 2         159672             Bactrim       Urinary Tract Infection
# 3          39293            Contrave                   Weight Loss
# 4          97768     Cyclafem 1 / 35                 Birth Control
# ...          ...                 ...                           ...
# 215058    191035             Campral            Alcohol Dependence
# 215059    127085      Metoclopramide               Nausea/Vomiting
# 215060    187382             Orencia          Rheumatoid Arthritis
# 215061     47128  Thyroid desiccated           Underactive Thyroid
# 215062    215220        Lubiprostone         Constipation, Chronic
#
#                                                    review  rating       date  \
# 0       "I&#039;ve tried a few antidepressants over th...      10  28-Feb-12
# 1       "My son has Crohn&#039;s disease and has done ...       8  17-May-09
# 2                           "Quick reduction of symptoms"       9  29-Sep-17
# 3       "Contrave combines drugs that were used for al...       9   5-Mar-17
# 4       "I have been on this birth control for one cyc...       9  22-Oct-15
# ...                                                   ...     ...        ...
# 215058  "I wrote my first report in Mid-October of 201...      10  31-May-15
# 215059  "I was given this in IV before surgey. I immed...       1   1-Nov-11
# 215060  "Limited improvement after 4 months, developed...       2  15-Mar-14
# 215061  "I&#039;ve been on thyroid medication 49 years...      10  19-Sep-15
# 215062  "I&#039;ve had chronic constipation all my adu...       9  13-Dec-14
#
#         usefulCount
# 0                22
# 1                17
# 2                 3
# 3                35
# 4                 4
# ...             ...
# 215058          125
# 215059           34
# 215060           35
# 215061           79
# 215062          116
#
# [215063 rows x 7 columns]

# %%
drugs_pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215063 entries, 0 to 215062
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   uniqueID     215063 non-null  int64
#  1   drugName     215063 non-null  object
#  2   condition    213869 non-null  object
#  3   review       215063 non-null  object
#  4   rating       215063 non-null  int64
#  5   date         215063 non-null  object
#  6   usefulCount  215063 non-null  int64
# dtypes: int64(3), object(4)
# memory usage: 11.5+ MB

# %%
drugs_pd.describe()
# Out:
#             uniqueID         rating    usefulCount
# count  215063.000000  215063.000000  215063.000000
# mean   116039.364814       6.990008      28.001004
# std     67007.913366       3.275554      36.346069
# min         0.000000       1.000000       0.000000
# 25%     58115.500000       5.000000       6.000000
# 50%    115867.000000       8.000000      16.000000
# 75%    173963.500000      10.000000      36.000000
# max    232291.000000      10.000000    1291.000000

# %%
drugs_pd.isnull().sum()
# Out:
# uniqueID          0
# drugName          0
# condition      1194
# review            0
# rating            0
# date              0
# usefulCount       0
# dtype: int64

# %%
no_condition = drugs_pd.drop(drugs_pd[drugs_pd['condition'].isnull() == False].index).copy()

no_condition
# Out:
#         uniqueID                                    drugName condition  \
# 34         77164                                  Lorcaserin       NaN
# 146       192374            Drospirenone / ethinyl estradiol       NaN
# 156       165767                              Levonorgestrel       NaN
# 779       157589                                 Guaifenesin       NaN
# 1017       96918  Conjugated estrogens / medroxyprogesterone       NaN
# ...          ...                                         ...       ...
# 214234    117817                  Multivitamin with minerals       NaN
# 214266       657                         Medroxyprogesterone       NaN
# 214455    104844          Ethinyl estradiol / levonorgestrel       NaN
# 214518     41252                   Acetaminophen / oxycodone       NaN
# 214607    150516             Sulfamethoxazole / trimethoprim       NaN
#
#                                                    review  rating       date  \
# 34      "Have had back and leg pain and sometimes arm ...       5  27-May-14
# 146     "I hate this birth control. I was originally t...       4  13-Apr-15
# 156     "I&#039;ve never had kids and I am 32 fyi. The...       7   3-Apr-17
# 779     "You&#039;ll almost always notice a medicinal ...       9  23-Feb-10
# 1017    "Has not worked one bit still have day and nig...       1   6-Jul-15
# ...                                                   ...     ...        ...
# 214234  "Severe hives itching  after taking for 6 months"       5  15-Nov-15
# 214266  "I am 18 and I have been using the shot for 8 ...       6  20-Nov-11
# 214455  "I&#039;ve been on Loseasonique for about 2 we...      10  13-Apr-10
# 214518  "This is my third day using this pain medicine...      10  13-Dec-10
# 214607  "Given a 7 day course. After 2 days, insomnia,...       4  28-Sep-16
#
#         usefulCount
# 34               21
# 146               8
# 156               0
# 779              10
# 1017              5
# ...             ...
# 214234            0
# 214266            2
# 214455            3
# 214518            4
# 214607            3
#
# [1194 rows x 7 columns]

# %%
pattern = r'\w*</span>\w*'

check = list(drugs_pd['condition'].unique())
non_conditions = []

for cond in check:
    if type(cond) != float:
        if re.match(pattern, cond):
            non_conditions.append(cond)

non_condition = drugs_pd[drugs_pd['condition'].isin(non_conditions)].copy()
non_condition
# Out:
#         uniqueID               drugName  \
# 136        33560  Microgestin Fe 1 / 20
# 211       133232           Tri-Sprintec
# 348        60892          Kombiglyze XR
# 368        66762               Seroquel
# 572       156099                 Cialis
# ...          ...                    ...
# 214088    173464                   Alli
# 214557    150010                   Soma
# 214665    209239                 Geodon
# 214687     96527              Neurontin
# 214988    206868                   Duac
#
#                                           condition  \
# 136     12</span> users found this comment helpful.
# 211      0</span> users found this comment helpful.
# 348      6</span> users found this comment helpful.
# 368     24</span> users found this comment helpful.
# 572      9</span> users found this comment helpful.
# ...                                             ...
# 214088  99</span> users found this comment helpful.
# 214557  62</span> users found this comment helpful.
# 214665   7</span> users found this comment helpful.
# 214687  92</span> users found this comment helpful.
# 214988   7</span> users found this comment helpful.
#
#                                                    review  rating       date  \
# 136     I was really worried at first because of all t...       9  24-Dec-12
# 211     I have been off of birth control for 2 years. ...       5  20-Dec-11
# 348     This medicine is great, our patients no longer...      10   4-Oct-12
# 368     I've been taking this since January 2013 for d...       9  19-Sep-13
# 572     I took the pill Friday night and went to bed. ...      10   3-May-11
# ...                                                   ...     ...        ...
# 214088  Great pill... You can definitely see it workin...       9   2-Apr-15
# 214557  I am sharing a painful experience actually. Th...       5  11-Mar-10
# 214665  I've been taking Geodon for about a month or s...       7   4-Feb-11
# 214687        At 300mg 4x daily my pain was almost gone.        9   8-Jul-13
# 214988  Duac works great for my rosacea, the first med...      10   4-Dec-10
#
#         usefulCount
# 136              12
# 211               0
# 348               6
# 368              24
# 572               9
# ...             ...
# 214088           99
# 214557           62
# 214665            7
# 214687           92
# 214988            7
#
# [1171 rows x 7 columns]

# %%
noc_reviews = list(no_condition['review'])
nonc_reviews = list(non_condition['review'])

def clean_review(reviews):
    clean = list()
    pattern_unusual = r'.*%u2019.*'
    
    for rev in reviews:
        cleaned = (re.sub(r'%u2019', "'", rev) if re.match(pattern_unusual, rev) else html.unescape(rev))
        clean.append(cleaned.strip('"'))
        
    return clean

no_condition['review'] = clean_review(noc_reviews)
non_condition['review'] = clean_review(nonc_reviews)

# %%
drugs_pd.update(no_condition['review'])
drugs_pd.update(non_condition['review'])

conditions = drugs_pd[(~drugs_pd.index.isin(non_condition.index)) & (~drugs_pd.index.isin(no_condition.index))].copy()
conditon_reviews = list(conditions['review'])

conditions['review'] = clean_review(conditon_reviews)
drugs_pd.update(conditions['review'])

cleaned_drugs = drugs_pd.copy()

# %%
# work with this
cleaned_drugs
# Out:
#         uniqueID            drugName                     condition  \
# 0         163740         Mirtazapine                    Depression
# 1         206473          Mesalamine  Crohn's Disease, Maintenance
# 2         159672             Bactrim       Urinary Tract Infection
# 3          39293            Contrave                   Weight Loss
# 4          97768     Cyclafem 1 / 35                 Birth Control
# ...          ...                 ...                           ...
# 215058    191035             Campral            Alcohol Dependence
# 215059    127085      Metoclopramide               Nausea/Vomiting
# 215060    187382             Orencia          Rheumatoid Arthritis
# 215061     47128  Thyroid desiccated           Underactive Thyroid
# 215062    215220        Lubiprostone         Constipation, Chronic
#
#                                                    review  rating       date  \
# 0       I've tried a few antidepressants over the year...      10  28-Feb-12
# 1       My son has Crohn's disease and has done very w...       8  17-May-09
# 2                             Quick reduction of symptoms       9  29-Sep-17
# 3       Contrave combines drugs that were used for alc...       9   5-Mar-17
# 4       I have been on this birth control for one cycl...       9  22-Oct-15
# ...                                                   ...     ...        ...
# 215058  I wrote my first report in Mid-October of 2014...      10  31-May-15
# 215059  I was given this in IV before surgey. I immedi...       1   1-Nov-11
# 215060  Limited improvement after 4 months, developed ...       2  15-Mar-14
# 215061  I've been on thyroid medication 49 years, I sp...      10  19-Sep-15
# 215062  I've had chronic constipation all my adult lif...       9  13-Dec-14
#
#         usefulCount
# 0                22
# 1                17
# 2                 3
# 3                35
# 4                 4
# ...             ...
# 215058          125
# 215059           34
# 215060           35
# 215061           79
# 215062          116
#
# [215063 rows x 7 columns]

# %%
def deconstruct(phrase):
    # specific
    phrase = re.sub(r"won\'t", "will not", phrase)
    phrase = re.sub(r"can\'t", "can not", phrase)

    # general
    phrase = re.sub(r"n\'t", " not", phrase)
    phrase = re.sub(r"\'re", " are", phrase)
    phrase = re.sub(r"\'s", " is", phrase)
    phrase = re.sub(r"\'d", " would", phrase)
    phrase = re.sub(r"\'ll", " will", phrase)
    phrase = re.sub(r"\'t", " not", phrase)
    phrase = re.sub(r"\'ve", " have", phrase)
    phrase = re.sub(r"\'m", " am", phrase)
    return phrase

cleaned_drugs['review'] = cleaned_drugs['review'].apply(deconstruct)
cleaned_drugs
# Out:
#         uniqueID            drugName                     condition  \
# 0         163740         Mirtazapine                    Depression
# 1         206473          Mesalamine  Crohn's Disease, Maintenance
# 2         159672             Bactrim       Urinary Tract Infection
# 3          39293            Contrave                   Weight Loss
# 4          97768     Cyclafem 1 / 35                 Birth Control
# ...          ...                 ...                           ...
# 215058    191035             Campral            Alcohol Dependence
# 215059    127085      Metoclopramide               Nausea/Vomiting
# 215060    187382             Orencia          Rheumatoid Arthritis
# 215061     47128  Thyroid desiccated           Underactive Thyroid
# 215062    215220        Lubiprostone         Constipation, Chronic
#
#                                                    review  rating       date  \
# 0       I have tried a few antidepressants over the ye...      10  28-Feb-12
# 1       My son has Crohn is disease and has done very ...       8  17-May-09
# 2                             Quick reduction of symptoms       9  29-Sep-17
# 3       Contrave combines drugs that were used for alc...       9   5-Mar-17
# 4       I have been on this birth control for one cycl...       9  22-Oct-15
# ...                                                   ...     ...        ...
# 215058  I wrote my first report in Mid-October of 2014...      10  31-May-15
# 215059  I was given this in IV before surgey. I immedi...       1   1-Nov-11
# 215060  Limited improvement after 4 months, developed ...       2  15-Mar-14
# 215061  I have been on thyroid medication 49 years, I ...      10  19-Sep-15
# 215062  I have had chronic constipation all my adult l...       9  13-Dec-14
#
#         usefulCount
# 0                22
# 1                17
# 2                 3
# 3                35
# 4                 4
# ...             ...
# 215058          125
# 215059           34
# 215060           35
# 215061           79
# 215062          116
#
# [215063 rows x 7 columns]

# %% [markdown]
# ### Tasks:
#
# * exploratory data analysis (do graphs and stuff sa dataset (e.g. count yung number of drugs))
#
#
# * nlp sentiment analysis (search VADER for more info but tl:dr, magreresult siya ng apat na values that scores yung sentiment ng sentence na yun)
#
#
# * derive ng column to score yung actual rating based sa rating, sentiment score, and yung usefulCount
#
#
# * idk paano iapply yung cosine and jaccard similarity... but yes ahaha
